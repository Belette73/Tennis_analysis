# %%
# Import des packages généraux
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('atp_matches_2017.csv')
df.head()
# Out:
#                                                                                                                                    tourney_id  \
# 2017-M020 Brisbane Hard 32 A 20170102 300 105777 7.0 NaN Grigor Dimitrov R 188.0 BUL 25.634497 17.0 2035.0 105453 3.0 NaN       Kei Nishikori
#                                       299 105777 7.0 NaN Grigor Dimitrov R 188.0 BUL 25.634497 17.0 2035.0 105683 1.0 NaN        Milos Raonic
#                                       298 105453 3.0 NaN Kei Nishikori   R 178.0 JPN 27.011636 5.0  4905.0 104527 2.0 NaN  Stanislas Wawrinka
#                                       297 105683 1.0 NaN Milos Raonic    R 196.0 CAN 26.017796 3.0  5450.0 104745 5.0 NaN        Rafael Nadal
#                                       296 105777 7.0 NaN Grigor Dimitrov R 188.0 BUL 25.634497 17.0 2035.0 106233 4.0 NaN       Dominic Thiem
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 388 entries, ('2017-M020', 'Brisbane', 'Hard', 32, 'A', 20170102, 300, 105777, 7.0, nan, 'Grigor Dimitrov', 'R', 188.0, 'BUL', 25.6344969199, 17.0, 2035.0, 105453, 3.0, nan) to ('2017-M-DC-2017-WG-M-SUI-USA-01', 'Davis Cup WG R1: SUI vs USA', 'Hard', 4, 'D', 20170203, 5, 105449, nan, nan, 'Steve Johnson', 'R', 188.0, 'USA', 27.1019849418, 31.0, 1345.0, 134472, nan, nan)
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          388 non-null    object
#  1   tourney_name        386 non-null    object
#  2   surface             188 non-null    float64
#  3   draw_size           388 non-null    object
#  4   tourney_level       386 non-null    float64
#  5   tourney_date        366 non-null    float64
#  6   match_num           366 non-null    float64
#  7   winner_id           388 non-null    object
# ...

# %%
df.shape
# Out:
# (388, 49)
